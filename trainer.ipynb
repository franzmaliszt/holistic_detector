# %%
import os

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score
import pickle

import cv2
import numpy as np

from mediapipe.python.solutions import drawing_utils as mp_drawing
from mediapipe.python.solutions import holistic as mp_holistic

# %%
df = pd.read_csv('coordinates.csv')
df.dropna(inplace=True)

# %%
df.head()
# Out:
#      class        x1        y1        z1        v1        x2        y2  \
# 0  onphone  0.328635  0.429501 -0.545699  0.999715  0.357870  0.377662
# 1  onphone  0.328712  0.428614 -0.615895  0.999713  0.357924  0.377663
# 2  onphone  0.328689  0.427790 -0.632160  0.999718  0.357870  0.377635
# 3  onphone  0.328687  0.428207 -0.555022  0.999706  0.357885  0.378165
# 4  onphone  0.328650  0.429459 -0.549788  0.999651  0.357896  0.379126
#
#          z2        v2        x3  ...      z499  v499      x500      y500  \
# 0 -0.513882  0.998970  0.373069  ... -0.003363   0.0  0.378759  0.367419
# 1 -0.572709  0.998949  0.373282  ... -0.004115   0.0  0.379162  0.364425
# 2 -0.587004  0.998951  0.373285  ... -0.004626   0.0  0.381348  0.362481
# 3 -0.516839  0.998898  0.373417  ... -0.004487   0.0  0.382253  0.362935
# 4 -0.514216  0.998677  0.373497  ... -0.003797   0.0  0.383240  0.363496
#
#        z500  v500      x501      y501      z501  v501
# 0  0.002722   0.0  0.383056  0.360641  0.002427   0.0
# 1  0.002475   0.0  0.383338  0.359364  0.002037   0.0
# 2  0.001779   0.0  0.385641  0.357448  0.001243   0.0
# 3  0.002303   0.0  0.386400  0.358029  0.001816   0.0
# 4  0.002815   0.0  0.387517  0.358570  0.002309   0.0
#
# [5 rows x 2005 columns]

# %%
X = df.drop('class', axis=1)
y = df['class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1111)

# %%
pipelines = {
    'lr': make_pipeline(StandardScaler(), LogisticRegression()),
    'rc': make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf': make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb': make_pipeline(StandardScaler(), GradientBoostingClassifier())
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 1.0
# rc 1.0
# rf 1.0
# gb 1.0

# %%
with open('body_language.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['break', 'onphone', 'onphone', 'sleepy', 'break', 'break',
#        'sleepy', 'sleepy', 'sleepy', 'sleepy', 'onphone', 'onphone',
#        'onphone', 'break', 'sleepy', 'onphone', 'break', 'sleepy',
#        'onphone', 'sleepy', 'onphone', 'sleepy', 'onphone', 'sleepy',
#        'break', 'sleepy', 'sleepy', 'break', 'onphone', 'onphone',
#        'sleepy', 'break', 'sleepy', 'break', 'sleepy', 'sleepy', 'sleepy',
#        'sleepy', 'break', 'break', 'break', 'onphone', 'onphone', 'break',
#        'sleepy', 'onphone', 'sleepy', 'sleepy', 'break', 'sleepy',
#        'onphone', 'break', 'onphone', 'break', 'break', 'sleepy', 'break',
#        'sleepy', 'break', 'onphone', 'break', 'onphone', 'sleepy',
#        'onphone', 'onphone', 'sleepy', 'break', 'sleepy', 'sleepy',
#        'break', 'onphone', 'onphone', 'break', 'onphone', 'onphone',
#        'sleepy', 'break', 'sleepy', 'onphone', 'break', 'sleepy',
#        'onphone', 'break', 'onphone', 'sleepy', 'onphone', 'sleepy',
#        'break', 'onphone', 'break', 'sleepy', 'break', 'onphone', 'break',
#        'sleepy', 'onphone', 'break', 'break', 'onphone', 'break',
#        'sleepy', 'sleepy', 'sleepy', 'break', 'onphone', 'onphone',
#        'break', 'break', 'onphone', 'onphone', 'break', 'sleepy',
#        'onphone', 'break', 'break', 'onphone', 'sleepy', 'sleepy',
#        'onphone', 'break', 'sleepy', 'onphone', 'break', 'break',
#        'sleepy', 'break', 'onphone', 'sleepy', 'sleepy', 'break',
#        'sleepy', 'sleepy', 'break', 'break', 'break', 'break', 'break',
#        'onphone', 'break', 'break', 'break', 'break', 'onphone', 'sleepy',
#        'onphone', 'onphone', 'onphone', 'sleepy', 'break', 'onphone',
#        'break', 'break', 'break', 'break', 'onphone', 'break', 'break',
#        'break', 'onphone', 'onphone', 'sleepy', 'break', 'sleepy',
#        'sleepy', 'break', 'onphone', 'onphone', 'break', 'break', 'break',
#        'sleepy', 'break', 'onphone', 'onphone', 'break', 'break',
#        'onphone', 'break', 'sleepy', 'break', 'break', 'onphone',
#        'sleepy', 'sleepy', 'sleepy', 'sleepy', 'onphone', 'onphone',
#        'break', 'onphone', 'break', 'sleepy', 'sleepy', 'sleepy',
#        'onphone', 'onphone', 'onphone', 'break', 'sleepy', 'break',
#        'break', 'sleepy', 'onphone', 'onphone', 'break', 'onphone',
#        'sleepy', 'onphone', 'onphone', 'break', 'sleepy', 'onphone',
#        'sleepy', 'sleepy', 'break', 'onphone', 'onphone', 'break',
#        'sleepy', 'break', 'break', 'break', 'break', 'sleepy', 'sleepy',
#        'onphone', 'sleepy', 'sleepy', 'break', 'onphone', 'sleepy',
#        'sleepy', 'break', 'break', 'sleepy', 'sleepy', 'sleepy',
#        'onphone', 'break', 'sleepy', 'break', 'sleepy', 'sleepy', 'break',
#        'onphone', 'break', 'sleepy', 'onphone', 'onphone', 'onphone',
#        'onphone', 'sleepy', 'onphone', 'break', 'onphone', 'sleepy',
#        'onphone', 'break', 'onphone'], dtype=object)
